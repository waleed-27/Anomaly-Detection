# %% [markdown]
# #Downloading Repos
#
# * Contains code to format visa dataset into mvtect
# * Diffusion-AD model repo

# %%
# !git clone https://github.com/amazon-science/spot-diff.git
# !git clone https://github.com/HuiZhang0812/DiffusionAD.git
# Out:
# Cloning into 'spot-diff'...
# remote: Enumerating objects: 65, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 65 (delta 31), reused 47 (delta 17), pack-reused 0
# Receiving objects: 100% (65/65), 2.42 MiB | 12.10 MiB/s, done.
# Resolving deltas: 100% (31/31), done.
# Cloning into 'DiffusionAD'...
# remote: Enumerating objects: 78, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 78 (delta 17), reused 16 (delta 16), pack-reused 57
# Receiving objects: 100% (78/78), 2.27 MiB | 12.91 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %% [markdown]
# #Downloading VISA Dataset

# %%
# !mkdir visa
# %cd /content/visa
# !wget https://amazon-visual-anomaly.s3.us-west-2.amazonaws.com/VisA_20220922.tar
# !tar -xf /content/visa/VisA_20220922.tar
# %cd ..
# Out:
# /content/visa
# --2024-05-19 13:01:12--  https://amazon-visual-anomaly.s3.us-west-2.amazonaws.com/VisA_20220922.tar
# Resolving amazon-visual-anomaly.s3.us-west-2.amazonaws.com (amazon-visual-anomaly.s3.us-west-2.amazonaws.com)... 3.5.86.121, 52.92.179.10, 3.5.86.211, ...
# Connecting to amazon-visual-anomaly.s3.us-west-2.amazonaws.com (amazon-visual-anomaly.s3.us-west-2.amazonaws.com)|3.5.86.121|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1929840640 (1.8G) [application/x-tar]
# Saving to: ‘VisA_20220922.tar’
#
# VisA_20220922.tar   100%[===================>]   1.80G  43.1MB/s    in 38s
#
# 2024-05-19 13:01:51 (48.3 MB/s) - ‘VisA_20220922.tar’ saved [1929840640/1929840640]
#
# /content

# %% [markdown]
# # Downloading DTD Dataset

# %%
# !wget https://www.robots.ox.ac.uk/~vgg/data/dtd/download/dtd-r1.0.1.tar.gz
# Out:
# --2024-05-19 13:02:01--  https://www.robots.ox.ac.uk/~vgg/data/dtd/download/dtd-r1.0.1.tar.gz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/datasets/dtd/dtd-r1.0.1.tar.gz [following]
# --2024-05-19 13:02:02--  https://thor.robots.ox.ac.uk/datasets/dtd/dtd-r1.0.1.tar.gz
# Resolving thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)... 129.67.95.98
# Connecting to thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)|129.67.95.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 625239812 (596M) [application/octet-stream]
# Saving to: ‘dtd-r1.0.1.tar.gz’
#
# dtd-r1.0.1.tar.gz   100%[===================>] 596.27M  35.0MB/s    in 18s
#
# 2024-05-19 13:02:20 (33.2 MB/s) - ‘dtd-r1.0.1.tar.gz’ saved [625239812/625239812]

# %%
# !tar -xf dtd-r1.0.1.tar.gz

# %% [markdown]
# #Converting VISA dataset to mvtec Format

# %%
# !mkdir VISA_PCB
# %cd /content/spot-diff
# !python ./utils/prepare_data.py --split-type 1cls --data-folder /content/visa --save-folder /content/VISA_PCB --split-file ./split_csv/1cls.csv
# %cd ..
# Out:
# /content/spot-diff
# /content

# %%
# !python ./utils/prepare_data.py --split-type 1cls --data-folder /home/work/Chest_Data/repos/DiffusionAD/visa_org --save-folder /home/work/Chest_Data/repos/DiffusionAD/datasets/visa --split-file ./split_csv/1cls.csv
# Out:
# python3: can't open file '/content/./utils/prepare_data.py': [Errno 2] No such file or directory

# %% [markdown]
# #Downloading Foregrounds

# %%
# !gdown 1vEzdL8busWHx_yo_rnEKSUfq0g_pjA5w
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1vEzdL8busWHx_yo_rnEKSUfq0g_pjA5w
# From (redirected): https://drive.google.com/uc?id=1vEzdL8busWHx_yo_rnEKSUfq0g_pjA5w&confirm=t&uuid=9e3db7ed-539a-4ee8-9e1b-02c7913b093f
# To: /content/visa-20240517T105044Z-001.zip
# 100% 323M/323M [00:03<00:00, 83.8MB/s]

# %%
# !unzip visa-20240517T105044Z-001.zip -d /content/foreground
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/foreground/visa/candle/DISthresh/good/0472.JPG
#   inflating: /content/foreground/visa/capsules/DISthresh/good/189.JPG
#   inflating: /content/foreground/visa/candle/DISthresh/good/0448.JPG
#   inflating: /content/foreground/visa/candle/DISthresh/good/0453.JPG
#   inflating: /content/foreground/visa/pcb3/DISthresh/good/0227.JPG
#   inflating: /content/foreground/visa/pcb3/DISthresh/good/0828.JPG
#   inflating: /content/foreground/visa/candle/DISthresh/good/0461.JPG
#   inflating: /content/foreground/visa/candle/DISthresh/good/0463.JPG
#   inflating: /content/foreground/visa/pcb3/DISthresh/good/0321.JPG
#   inflating: /content/foreground/visa/candle/DISthresh/good/0474.JPG
#   inflating: /content/foreground/visa/candle/DISthresh/good/0487.JPG
#   inflating: /content/foreground/visa/candle/DISthresh/good/0449.JPG
#   inflating: /content/foreground/visa/pcb3/DISthresh/good/0769.JPG
# ...

# %%
# %cp -r /content/foreground/visa/pcb1/DISthresh/ /content/VISA_PCB/1cls/pcb1
# %cp -r /content/foreground/visa/pcb2/DISthresh/ /content/VISA_PCB/1cls/pcb2
# %cp -r /content/foreground/visa/pcb3/DISthresh/ /content/VISA_PCB/1cls/pcb3
# %cp -r /content/foreground/visa/pcb4/DISthresh/ /content/VISA_PCB/1cls/pcb4

# %% [markdown]
# #Setting up enviornemnt

# %%
# %cd /content/DiffusionAD
# Out:
# /content/DiffusionAD

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 16.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 5.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Change paths of datasets in /content/DiffusionAD/args/args1.json
#
# ```
#  "visa_root_path":"/content/VISA_PCB/1cls"
#  "anomaly_source_path":"/content/dtd"
# ```

# %% [markdown]
# #Training Models

# %%
# %cd /content/DiffusionAD
# Out:
# /content/DiffusionAD

# %%
# !python train.py

# %% [markdown]
# #Evaluating Models

# %%
# !python eval.py
